# %%
# import libraries
import pandas as pd
import seaborn as sns

# %%
# read in the data...
df = pd.read_csv('stock_prices.csv', sep='|', parse_dates=['date'])

# %%
# check our data types after we've imported them (integers, dates, etc?!)
df.dtypes
# Out:
# symbol            object
# price            float64
# date      datetime64[ns]
# dtype: object

# %%
# plot some data...
sns.lineplot(data=df, x='date', y='price');

# %%
# describe the price column...
df['price'].describe()
# Out:
# count     4.000000
# mean     10.875000
# std       1.547848
# min       9.500000
# 25%       9.875000
# 50%      10.500000
# 75%      11.500000
# max      13.000000
# Name: price, dtype: float64
